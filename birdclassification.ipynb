# %% [markdown]
# # Bài 1: Bird Species Classification (40 pts)
#
# Cho tập data Bird Species gồm ~84k ảnh của 525 nhãn, mỗi nhãn là tên khoa học của 1 loại chim tại Kaggle: https://www.kaggle.com/datasets/gpiosenka/100-bird-species. Yêu cầu:
#
# 1. Sử dụng các kiến thức đã học (CNN, Transfer Learning), tạo 1 cấu trúc mô hình phù hợp để phân loại 525 nhãn.

# %% [markdown]
# ## 1. Load Data

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets, models
from sklearn.model_selection import train_test_split

# %%
# Thiết lập các tham số
batch_size = 32
learning_rate = 0.001
num_epochs = 10

# Đường dẫn đến tập dữ liệu
data_dir = "/kaggle/input/100-bird-species/"

# Áp dụng các biến đổi cho dữ liệu huấn luyện và kiểm thử
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# %%
# Tạo DataLoader cho dữ liệu huấn luyện và kiểm thử 
# ImageFolder => label encoder already included
train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=transform_train)
test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=transform_test)
valid_dataset = datasets.ImageFolder(root=data_dir + 'valid', transform=transform_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# %%
# Số lượng mẫu
len(train_dataset)
# Out:
# 84635

# %%
# Print all the classes
classes = train_dataset.classes
print("Len of train Classes:",len(classes))
print("Len of test Classes:",len(test_dataset.classes))

# Get the class-to-index mapping
class_to_idx = train_dataset.class_to_idx

# Print classes with their indices
for class_name, class_idx in class_to_idx.items():
    print(f"Class: {class_name}, Index: {class_idx}")
# Out:
# Len of train Classes: 525
# Len of test Classes: 525
# Class: ABBOTTS BABBLER, Index: 0
# Class: ABBOTTS BOOBY, Index: 1
# Class: ABYSSINIAN GROUND HORNBILL, Index: 2
# Class: AFRICAN CROWNED CRANE, Index: 3
# Class: AFRICAN EMERALD CUCKOO, Index: 4
# Class: AFRICAN FIREFINCH, Index: 5
# Class: AFRICAN OYSTER CATCHER, Index: 6
# Class: AFRICAN PIED HORNBILL, Index: 7
# Class: AFRICAN PYGMY GOOSE, Index: 8
# Class: ALBATROSS, Index: 9
# Class: ALBERTS TOWHEE, Index: 10
# Class: ALEXANDRINE PARAKEET, Index: 11
# Class: ALPINE CHOUGH, Index: 12
# Class: ALTAMIRA YELLOWTHROAT, Index: 13
# Class: AMERICAN AVOCET, Index: 14
# Class: AMERICAN BITTERN, Index: 15
# Class: AMERICAN COOT, Index: 16
# Class: AMERICAN DIPPER, Index: 17
# Class: AMERICAN FLAMINGO, Index: 18
# Class: AMERICAN GOLDFINCH, Index: 19
# Class: AMERICAN KESTREL, Index: 20
# Class: AMERICAN PIPIT, Index: 21
# Class: AMERICAN REDSTART, Index: 22
# Class: AMERICAN ROBIN, Index: 23
# Class: AMERICAN WIGEON, Index: 24
# Class: AMETHYST WOODSTAR, Index: 25
# Class: ANDEAN GOOSE, Index: 26
# Class: ANDEAN LAPWING, Index: 27
# Class: ANDEAN SISKIN, Index: 28
# Class: ANHINGA, Index: 29
# Class: ANIANIAU, Index: 30
# Class: ANNAS HUMMINGBIRD, Index: 31
# Class: ANTBIRD, Index: 32
# Class: ANTILLEAN EUPHONIA, Index: 33
# Class: APAPANE, Index: 34
# Class: APOSTLEBIRD, Index: 35
# Class: ARARIPE MANAKIN, Index: 36
# Class: ASHY STORM PETREL, Index: 37
# Class: ASHY THRUSHBIRD, Index: 38
# Class: ASIAN CRESTED IBIS, Index: 39
# Class: ASIAN DOLLARD BIRD, Index: 40
# Class: ASIAN GREEN BEE EATER, Index: 41
# Class: ASIAN OPENBILL STORK, Index: 42
# Class: AUCKLAND SHAQ, Index: 43
# Class: AUSTRAL CANASTERO, Index: 44
# Class: AUSTRALASIAN FIGBIRD, Index: 45
# Class: AVADAVAT, Index: 46
# Class: AZARAS SPINETAIL, Index: 47
# Class: AZURE BREASTED PITTA, Index: 48
# Class: AZURE JAY, Index: 49
# Class: AZURE TANAGER, Index: 50
# Class: AZURE TIT, Index: 51
# Class: BAIKAL TEAL, Index: 52
# Class: BALD EAGLE, Index: 53
# Class: BALD IBIS, Index: 54
# Class: BALI STARLING, Index: 55
# Class: BALTIMORE ORIOLE, Index: 56
# Class: BANANAQUIT, Index: 57
# Class: BAND TAILED GUAN, Index: 58
# Class: BANDED BROADBILL, Index: 59
# Class: BANDED PITA, Index: 60
# Class: BANDED STILT, Index: 61
# Class: BAR-TAILED GODWIT, Index: 62
# Class: BARN OWL, Index: 63
# Class: BARN SWALLOW, Index: 64
# Class: BARRED PUFFBIRD, Index: 65
# Class: BARROWS GOLDENEYE, Index: 66
# Class: BAY-BREASTED WARBLER, Index: 67
# Class: BEARDED BARBET, Index: 68
# Class: BEARDED BELLBIRD, Index: 69
# Class: BEARDED REEDLING, Index: 70
# Class: BELTED KINGFISHER, Index: 71
# Class: BIRD OF PARADISE, Index: 72
# Class: BLACK AND YELLOW BROADBILL, Index: 73
# Class: BLACK BAZA, Index: 74
# Class: BLACK BREASTED PUFFBIRD, Index: 75
# Class: BLACK COCKATO, Index: 76
# Class: BLACK FACED SPOONBILL, Index: 77
# Class: BLACK FRANCOLIN, Index: 78
# Class: BLACK HEADED CAIQUE, Index: 79
# Class: BLACK NECKED STILT, Index: 80
# Class: BLACK SKIMMER, Index: 81
# Class: BLACK SWAN, Index: 82
# Class: BLACK TAIL CRAKE, Index: 83
# Class: BLACK THROATED BUSHTIT, Index: 84
# Class: BLACK THROATED HUET, Index: 85
# Class: BLACK THROATED WARBLER, Index: 86
# Class: BLACK VENTED SHEARWATER, Index: 87
# Class: BLACK VULTURE, Index: 88
# Class: BLACK-CAPPED CHICKADEE, Index: 89
# Class: BLACK-NECKED GREBE, Index: 90
# Class: BLACK-THROATED SPARROW, Index: 91
# Class: BLACKBURNIAM WARBLER, Index: 92
# Class: BLONDE CRESTED WOODPECKER, Index: 93
# Class: BLOOD PHEASANT, Index: 94
# Class: BLUE COAU, Index: 95
# Class: BLUE DACNIS, Index: 96
# Class: BLUE GRAY GNATCATCHER, Index: 97
# Class: BLUE GROSBEAK, Index: 98
# Class: BLUE GROUSE, Index: 99
# Class: BLUE HERON, Index: 100
# Class: BLUE MALKOHA, Index: 101
# Class: BLUE THROATED PIPING GUAN, Index: 102
# Class: BLUE THROATED TOUCANET, Index: 103
# Class: BOBOLINK, Index: 104
# Class: BORNEAN BRISTLEHEAD, Index: 105
# Class: BORNEAN LEAFBIRD, Index: 106
# Class: BORNEAN PHEASANT, Index: 107
# Class: BRANDT CORMARANT, Index: 108
# Class: BREWERS BLACKBIRD, Index: 109
# Class: BROWN CREPPER, Index: 110
# Class: BROWN HEADED COWBIRD, Index: 111
# Class: BROWN NOODY, Index: 112
# Class: BROWN THRASHER, Index: 113
# Class: BUFFLEHEAD, Index: 114
# Class: BULWERS PHEASANT, Index: 115
# Class: BURCHELLS COURSER, Index: 116
# Class: BUSH TURKEY, Index: 117
# Class: CAATINGA CACHOLOTE, Index: 118
# Class: CABOTS TRAGOPAN, Index: 119
# Class: CACTUS WREN, Index: 120
# Class: CALIFORNIA CONDOR, Index: 121
# Class: CALIFORNIA GULL, Index: 122
# Class: CALIFORNIA QUAIL, Index: 123
# Class: CAMPO FLICKER, Index: 124
# Class: CANARY, Index: 125
# Class: CANVASBACK, Index: 126
# Class: CAPE GLOSSY STARLING, Index: 127
# Class: CAPE LONGCLAW, Index: 128
# Class: CAPE MAY WARBLER, Index: 129
# Class: CAPE ROCK THRUSH, Index: 130
# Class: CAPPED HERON, Index: 131
# Class: CAPUCHINBIRD, Index: 132
# Class: CARMINE BEE-EATER, Index: 133
# Class: CASPIAN TERN, Index: 134
# Class: CASSOWARY, Index: 135
# Class: CEDAR WAXWING, Index: 136
# Class: CERULEAN WARBLER, Index: 137
# Class: CHARA DE COLLAR, Index: 138
# Class: CHATTERING LORY, Index: 139
# Class: CHESTNET BELLIED EUPHONIA, Index: 140
# Class: CHESTNUT WINGED CUCKOO, Index: 141
# Class: CHINESE BAMBOO PARTRIDGE, Index: 142
# Class: CHINESE POND HERON, Index: 143
# Class: CHIPPING SPARROW, Index: 144
# Class: CHUCAO TAPACULO, Index: 145
# Class: CHUKAR PARTRIDGE, Index: 146
# Class: CINNAMON ATTILA, Index: 147
# Class: CINNAMON FLYCATCHER, Index: 148
# Class: CINNAMON TEAL, Index: 149
# Class: CLARKS GREBE, Index: 150
# Class: CLARKS NUTCRACKER, Index: 151
# Class: COCK OF THE  ROCK, Index: 152
# Class: COCKATOO, Index: 153
# Class: COLLARED ARACARI, Index: 154
# Class: COLLARED CRESCENTCHEST, Index: 155
# Class: COMMON FIRECREST, Index: 156
# Class: COMMON GRACKLE, Index: 157
# Class: COMMON HOUSE MARTIN, Index: 158
# Class: COMMON IORA, Index: 159
# Class: COMMON LOON, Index: 160
# Class: COMMON POORWILL, Index: 161
# Class: COMMON STARLING, Index: 162
# Class: COPPERSMITH BARBET, Index: 163
# Class: COPPERY TAILED COUCAL, Index: 164
# Class: CRAB PLOVER, Index: 165
# Class: CRANE HAWK, Index: 166
# Class: CREAM COLORED WOODPECKER, Index: 167
# Class: CRESTED AUKLET, Index: 168
# Class: CRESTED CARACARA, Index: 169
# Class: CRESTED COUA, Index: 170
# Class: CRESTED FIREBACK, Index: 171
# Class: CRESTED KINGFISHER, Index: 172
# Class: CRESTED NUTHATCH, Index: 173
# Class: CRESTED OROPENDOLA, Index: 174
# Class: CRESTED SERPENT EAGLE, Index: 175
# Class: CRESTED SHRIKETIT, Index: 176
# Class: CRESTED WOOD PARTRIDGE, Index: 177
# Class: CRIMSON CHAT, Index: 178
# Class: CRIMSON SUNBIRD, Index: 179
# Class: CROW, Index: 180
# Class: CUBAN TODY, Index: 181
# Class: CUBAN TROGON, Index: 182
# Class: CURL CRESTED ARACURI, Index: 183
# Class: D-ARNAUDS BARBET, Index: 184
# Class: DALMATIAN PELICAN, Index: 185
# Class: DARJEELING WOODPECKER, Index: 186
# Class: DARK EYED JUNCO, Index: 187
# Class: DAURIAN REDSTART, Index: 188
# Class: DEMOISELLE CRANE, Index: 189
# Class: DOUBLE BARRED FINCH, Index: 190
# Class: DOUBLE BRESTED CORMARANT, Index: 191
# Class: DOUBLE EYED FIG PARROT, Index: 192
# Class: DOWNY WOODPECKER, Index: 193
# Class: DUNLIN, Index: 194
# Class: DUSKY LORY, Index: 195
# Class: DUSKY ROBIN, Index: 196
# Class: EARED PITA, Index: 197
# Class: EASTERN BLUEBIRD, Index: 198
# Class: EASTERN BLUEBONNET, Index: 199
# Class: EASTERN GOLDEN WEAVER, Index: 200
# Class: EASTERN MEADOWLARK, Index: 201
# Class: EASTERN ROSELLA, Index: 202
# Class: EASTERN TOWEE, Index: 203
# Class: EASTERN WIP POOR WILL, Index: 204
# Class: EASTERN YELLOW ROBIN, Index: 205
# Class: ECUADORIAN HILLSTAR, Index: 206
# Class: EGYPTIAN GOOSE, Index: 207
# Class: ELEGANT TROGON, Index: 208
# Class: ELLIOTS  PHEASANT, Index: 209
# Class: EMERALD TANAGER, Index: 210
# Class: EMPEROR PENGUIN, Index: 211
# Class: EMU, Index: 212
# Class: ENGGANO MYNA, Index: 213
# Class: EURASIAN BULLFINCH, Index: 214
# Class: EURASIAN GOLDEN ORIOLE, Index: 215
# Class: EURASIAN MAGPIE, Index: 216
# Class: EUROPEAN GOLDFINCH, Index: 217
# Class: EUROPEAN TURTLE DOVE, Index: 218
# Class: EVENING GROSBEAK, Index: 219
# Class: FAIRY BLUEBIRD, Index: 220
# Class: FAIRY PENGUIN, Index: 221
# Class: FAIRY TERN, Index: 222
# Class: FAN TAILED WIDOW, Index: 223
# Class: FASCIATED WREN, Index: 224
# Class: FIERY MINIVET, Index: 225
# Class: FIORDLAND PENGUIN, Index: 226
# Class: FIRE TAILLED MYZORNIS, Index: 227
# Class: FLAME BOWERBIRD, Index: 228
# Class: FLAME TANAGER, Index: 229
# Class: FOREST WAGTAIL, Index: 230
# Class: FRIGATE, Index: 231
# Class: FRILL BACK PIGEON, Index: 232
# Class: GAMBELS QUAIL, Index: 233
# Class: GANG GANG COCKATOO, Index: 234
# Class: GILA WOODPECKER, Index: 235
# Class: GILDED FLICKER, Index: 236
# Class: GLOSSY IBIS, Index: 237
# Class: GO AWAY BIRD, Index: 238
# Class: GOLD WING WARBLER, Index: 239
# Class: GOLDEN BOWER BIRD, Index: 240
# Class: GOLDEN CHEEKED WARBLER, Index: 241
# Class: GOLDEN CHLOROPHONIA, Index: 242
# Class: GOLDEN EAGLE, Index: 243
# Class: GOLDEN PARAKEET, Index: 244
# Class: GOLDEN PHEASANT, Index: 245
# Class: GOLDEN PIPIT, Index: 246
# Class: GOULDIAN FINCH, Index: 247
# Class: GRANDALA, Index: 248
# Class: GRAY CATBIRD, Index: 249
# Class: GRAY KINGBIRD, Index: 250
# Class: GRAY PARTRIDGE, Index: 251
# Class: GREAT ARGUS, Index: 252
# Class: GREAT GRAY OWL, Index: 253
# Class: GREAT JACAMAR, Index: 254
# Class: GREAT KISKADEE, Index: 255
# Class: GREAT POTOO, Index: 256
# Class: GREAT TINAMOU, Index: 257
# Class: GREAT XENOPS, Index: 258
# Class: GREATER PEWEE, Index: 259
# Class: GREATER PRAIRIE CHICKEN, Index: 260
# Class: GREATOR SAGE GROUSE, Index: 261
# Class: GREEN BROADBILL, Index: 262
# Class: GREEN JAY, Index: 263
# Class: GREEN MAGPIE, Index: 264
# Class: GREEN WINGED DOVE, Index: 265
# Class: GREY CUCKOOSHRIKE, Index: 266
# Class: GREY HEADED CHACHALACA, Index: 267
# Class: GREY HEADED FISH EAGLE, Index: 268
# Class: GREY PLOVER, Index: 269
# Class: GROVED BILLED ANI, Index: 270
# Class: GUINEA TURACO, Index: 271
# Class: GUINEAFOWL, Index: 272
# Class: GURNEYS PITTA, Index: 273
# Class: GYRFALCON, Index: 274
# Class: HAMERKOP, Index: 275
# Class: HARLEQUIN DUCK, Index: 276
# Class: HARLEQUIN QUAIL, Index: 277
# Class: HARPY EAGLE, Index: 278
# Class: HAWAIIAN GOOSE, Index: 279
# Class: HAWFINCH, Index: 280
# Class: HELMET VANGA, Index: 281
# Class: HEPATIC TANAGER, Index: 282
# Class: HIMALAYAN BLUETAIL, Index: 283
# Class: HIMALAYAN MONAL, Index: 284
# Class: HOATZIN, Index: 285
# Class: HOODED MERGANSER, Index: 286
# Class: HOOPOES, Index: 287
# Class: HORNED GUAN, Index: 288
# Class: HORNED LARK, Index: 289
# Class: HORNED SUNGEM, Index: 290
# Class: HOUSE FINCH, Index: 291
# Class: HOUSE SPARROW, Index: 292
# Class: HYACINTH MACAW, Index: 293
# Class: IBERIAN MAGPIE, Index: 294
# Class: IBISBILL, Index: 295
# Class: IMPERIAL SHAQ, Index: 296
# Class: INCA TERN, Index: 297
# Class: INDIAN BUSTARD, Index: 298
# Class: INDIAN PITTA, Index: 299
# Class: INDIAN ROLLER, Index: 300
# Class: INDIAN VULTURE, Index: 301
# Class: INDIGO BUNTING, Index: 302
# Class: INDIGO FLYCATCHER, Index: 303
# Class: INLAND DOTTEREL, Index: 304
# Class: IVORY BILLED ARACARI, Index: 305
# Class: IVORY GULL, Index: 306
# Class: IWI, Index: 307
# Class: JABIRU, Index: 308
# Class: JACK SNIPE, Index: 309
# Class: JACOBIN PIGEON, Index: 310
# Class: JANDAYA PARAKEET, Index: 311
# Class: JAPANESE ROBIN, Index: 312
# Class: JAVA SPARROW, Index: 313
# Class: JOCOTOCO ANTPITTA, Index: 314
# Class: KAGU, Index: 315
# Class: KAKAPO, Index: 316
# Class: KILLDEAR, Index: 317
# Class: KING EIDER, Index: 318
# Class: KING VULTURE, Index: 319
# Class: KIWI, Index: 320
# Class: KNOB BILLED DUCK, Index: 321
# Class: KOOKABURRA, Index: 322
# Class: LARK BUNTING, Index: 323
# Class: LAUGHING GULL, Index: 324
# Class: LAZULI BUNTING, Index: 325
# Class: LESSER ADJUTANT, Index: 326
# Class: LILAC ROLLER, Index: 327
# Class: LIMPKIN, Index: 328
# Class: LITTLE AUK, Index: 329
# Class: LOGGERHEAD SHRIKE, Index: 330
# Class: LONG-EARED OWL, Index: 331
# Class: LOONEY BIRDS, Index: 332
# Class: LUCIFER HUMMINGBIRD, Index: 333
# Class: MAGPIE GOOSE, Index: 334
# Class: MALABAR HORNBILL, Index: 335
# Class: MALACHITE KINGFISHER, Index: 336
# Class: MALAGASY WHITE EYE, Index: 337
# Class: MALEO, Index: 338
# Class: MALLARD DUCK, Index: 339
# Class: MANDRIN DUCK, Index: 340
# Class: MANGROVE CUCKOO, Index: 341
# Class: MARABOU STORK, Index: 342
# Class: MASKED BOBWHITE, Index: 343
# Class: MASKED BOOBY, Index: 344
# Class: MASKED LAPWING, Index: 345
# Class: MCKAYS BUNTING, Index: 346
# Class: MERLIN, Index: 347
# Class: MIKADO  PHEASANT, Index: 348
# Class: MILITARY MACAW, Index: 349
# Class: MOURNING DOVE, Index: 350
# Class: MYNA, Index: 351
# Class: NICOBAR PIGEON, Index: 352
# Class: NOISY FRIARBIRD, Index: 353
# Class: NORTHERN BEARDLESS TYRANNULET, Index: 354
# Class: NORTHERN CARDINAL, Index: 355
# Class: NORTHERN FLICKER, Index: 356
# Class: NORTHERN FULMAR, Index: 357
# Class: NORTHERN GANNET, Index: 358
# Class: NORTHERN GOSHAWK, Index: 359
# Class: NORTHERN JACANA, Index: 360
# Class: NORTHERN MOCKINGBIRD, Index: 361
# Class: NORTHERN PARULA, Index: 362
# Class: NORTHERN RED BISHOP, Index: 363
# Class: NORTHERN SHOVELER, Index: 364
# Class: OCELLATED TURKEY, Index: 365
# Class: OILBIRD, Index: 366
# Class: OKINAWA RAIL, Index: 367
# Class: ORANGE BREASTED TROGON, Index: 368
# Class: ORANGE BRESTED BUNTING, Index: 369
# Class: ORIENTAL BAY OWL, Index: 370
# Class: ORNATE HAWK EAGLE, Index: 371
# Class: OSPREY, Index: 372
# Class: OSTRICH, Index: 373
# Class: OVENBIRD, Index: 374
# Class: OYSTER CATCHER, Index: 375
# Class: PAINTED BUNTING, Index: 376
# Class: PALILA, Index: 377
# Class: PALM NUT VULTURE, Index: 378
# Class: PARADISE TANAGER, Index: 379
# Class: PARAKETT  AUKLET, Index: 380
# Class: PARUS MAJOR, Index: 381
# Class: PATAGONIAN SIERRA FINCH, Index: 382
# Class: PEACOCK, Index: 383
# Class: PEREGRINE FALCON, Index: 384
# Class: PHAINOPEPLA, Index: 385
# Class: PHILIPPINE EAGLE, Index: 386
# Class: PINK ROBIN, Index: 387
# Class: PLUSH CRESTED JAY, Index: 388
# Class: POMARINE JAEGER, Index: 389
# Class: PUFFIN, Index: 390
# Class: PUNA TEAL, Index: 391
# Class: PURPLE FINCH, Index: 392
# Class: PURPLE GALLINULE, Index: 393
# Class: PURPLE MARTIN, Index: 394
# Class: PURPLE SWAMPHEN, Index: 395
# Class: PYGMY KINGFISHER, Index: 396
# Class: PYRRHULOXIA, Index: 397
# Class: QUETZAL, Index: 398
# Class: RAINBOW LORIKEET, Index: 399
# Class: RAZORBILL, Index: 400
# Class: RED BEARDED BEE EATER, Index: 401
# Class: RED BELLIED PITTA, Index: 402
# Class: RED BILLED TROPICBIRD, Index: 403
# Class: RED BROWED FINCH, Index: 404
# Class: RED CROSSBILL, Index: 405
# Class: RED FACED CORMORANT, Index: 406
# Class: RED FACED WARBLER, Index: 407
# Class: RED FODY, Index: 408
# Class: RED HEADED DUCK, Index: 409
# Class: RED HEADED WOODPECKER, Index: 410
# Class: RED KNOT, Index: 411
# Class: RED LEGGED HONEYCREEPER, Index: 412
# Class: RED NAPED TROGON, Index: 413
# Class: RED SHOULDERED HAWK, Index: 414
# Class: RED TAILED HAWK, Index: 415
# Class: RED TAILED THRUSH, Index: 416
# Class: RED WINGED BLACKBIRD, Index: 417
# Class: RED WISKERED BULBUL, Index: 418
# Class: REGENT BOWERBIRD, Index: 419
# Class: RING-NECKED PHEASANT, Index: 420
# Class: ROADRUNNER, Index: 421
# Class: ROCK DOVE, Index: 422
# Class: ROSE BREASTED COCKATOO, Index: 423
# Class: ROSE BREASTED GROSBEAK, Index: 424
# Class: ROSEATE SPOONBILL, Index: 425
# Class: ROSY FACED LOVEBIRD, Index: 426
# Class: ROUGH LEG BUZZARD, Index: 427
# Class: ROYAL FLYCATCHER, Index: 428
# Class: RUBY CROWNED KINGLET, Index: 429
# Class: RUBY THROATED HUMMINGBIRD, Index: 430
# Class: RUDDY SHELDUCK, Index: 431
# Class: RUDY KINGFISHER, Index: 432
# Class: RUFOUS KINGFISHER, Index: 433
# Class: RUFOUS TREPE, Index: 434
# Class: RUFUOS MOTMOT, Index: 435
# Class: SAMATRAN THRUSH, Index: 436
# Class: SAND MARTIN, Index: 437
# Class: SANDHILL CRANE, Index: 438
# Class: SATYR TRAGOPAN, Index: 439
# Class: SAYS PHOEBE, Index: 440
# Class: SCARLET CROWNED FRUIT DOVE, Index: 441
# Class: SCARLET FACED LIOCICHLA, Index: 442
# Class: SCARLET IBIS, Index: 443
# Class: SCARLET MACAW, Index: 444
# Class: SCARLET TANAGER, Index: 445
# Class: SHOEBILL, Index: 446
# Class: SHORT BILLED DOWITCHER, Index: 447
# Class: SMITHS LONGSPUR, Index: 448
# Class: SNOW GOOSE, Index: 449
# Class: SNOW PARTRIDGE, Index: 450
# Class: SNOWY EGRET, Index: 451
# Class: SNOWY OWL, Index: 452
# Class: SNOWY PLOVER, Index: 453
# Class: SNOWY SHEATHBILL, Index: 454
# Class: SORA, Index: 455
# Class: SPANGLED COTINGA, Index: 456
# Class: SPLENDID WREN, Index: 457
# Class: SPOON BILED SANDPIPER, Index: 458
# Class: SPOTTED CATBIRD, Index: 459
# Class: SPOTTED WHISTLING DUCK, Index: 460
# Class: SQUACCO HERON, Index: 461
# Class: SRI LANKA BLUE MAGPIE, Index: 462
# Class: STEAMER DUCK, Index: 463
# Class: STORK BILLED KINGFISHER, Index: 464
# Class: STRIATED CARACARA, Index: 465
# Class: STRIPED OWL, Index: 466
# Class: STRIPPED MANAKIN, Index: 467
# Class: STRIPPED SWALLOW, Index: 468
# Class: SUNBITTERN, Index: 469
# Class: SUPERB STARLING, Index: 470
# Class: SURF SCOTER, Index: 471
# Class: SWINHOES PHEASANT, Index: 472
# Class: TAILORBIRD, Index: 473
# Class: TAIWAN MAGPIE, Index: 474
# Class: TAKAHE, Index: 475
# Class: TASMANIAN HEN, Index: 476
# Class: TAWNY FROGMOUTH, Index: 477
# Class: TEAL DUCK, Index: 478
# Class: TIT MOUSE, Index: 479
# Class: TOUCHAN, Index: 480
# Class: TOWNSENDS WARBLER, Index: 481
# Class: TREE SWALLOW, Index: 482
# Class: TRICOLORED BLACKBIRD, Index: 483
# Class: TROPICAL KINGBIRD, Index: 484
# Class: TRUMPTER SWAN, Index: 485
# Class: TURKEY VULTURE, Index: 486
# Class: TURQUOISE MOTMOT, Index: 487
# Class: UMBRELLA BIRD, Index: 488
# Class: VARIED THRUSH, Index: 489
# Class: VEERY, Index: 490
# Class: VENEZUELIAN TROUPIAL, Index: 491
# Class: VERDIN, Index: 492
# Class: VERMILION FLYCATHER, Index: 493
# Class: VICTORIA CROWNED PIGEON, Index: 494
# Class: VIOLET BACKED STARLING, Index: 495
# Class: VIOLET CUCKOO, Index: 496
# Class: VIOLET GREEN SWALLOW, Index: 497
# Class: VIOLET TURACO, Index: 498
# Class: VISAYAN HORNBILL, Index: 499
# Class: VULTURINE GUINEAFOWL, Index: 500
# Class: WALL CREAPER, Index: 501
# Class: WATTLED CURASSOW, Index: 502
# Class: WATTLED LAPWING, Index: 503
# Class: WHIMBREL, Index: 504
# Class: WHITE BREASTED WATERHEN, Index: 505
# Class: WHITE BROWED CRAKE, Index: 506
# Class: WHITE CHEEKED TURACO, Index: 507
# Class: WHITE CRESTED HORNBILL, Index: 508
# Class: WHITE EARED HUMMINGBIRD, Index: 509
# Class: WHITE NECKED RAVEN, Index: 510
# Class: WHITE TAILED TROPIC, Index: 511
# Class: WHITE THROATED BEE EATER, Index: 512
# Class: WILD TURKEY, Index: 513
# Class: WILLOW PTARMIGAN, Index: 514
# Class: WILSONS BIRD OF PARADISE, Index: 515
# Class: WOOD DUCK, Index: 516
# Class: WOOD THRUSH, Index: 517
# Class: WOODLAND KINGFISHER, Index: 518
# Class: WRENTIT, Index: 519
# Class: YELLOW BELLIED FLOWERPECKER, Index: 520
# Class: YELLOW BREASTED CHAT, Index: 521
# Class: YELLOW CACIQUE, Index: 522
# Class: YELLOW HEADED BLACKBIRD, Index: 523
# Class: ZEBRA DOVE, Index: 524

# %%
# In input và labels của batch đầu tiên
for batch_idx, (inputs, labels) in enumerate(train_loader):
    # Print the current batch
    print(f"Batch {batch_idx + 1} - Inputs: {inputs}, Labels: {labels}")

    # Print the size of the current batch (number of samples in the batch)
    print(f"Batch {batch_idx + 1} - Batch Size: {len(inputs)}")

    # Break after printing the first 5 batches
    if batch_idx == 0:
        break
# Out:
# Batch 1 - Inputs: tensor([[[[0.4510, 0.4471, 0.4510,  ..., 0.5490, 0.5569, 0.5647],
#           [0.4510, 0.4510, 0.4549,  ..., 0.5451, 0.5529, 0.5608],
#           [0.4471, 0.4471, 0.4510,  ..., 0.5451, 0.5529, 0.5569],
#           ...,
#           [0.4980, 0.5020, 0.4980,  ..., 0.3725, 0.3412, 0.3216],
#           [0.4941, 0.5020, 0.5020,  ..., 0.3686, 0.3373, 0.3176],
#           [0.4784, 0.4902, 0.5020,  ..., 0.3686, 0.3412, 0.3176]],
#
#          [[0.4549, 0.4510, 0.4549,  ..., 0.5451, 0.5529, 0.5569],
#           [0.4549, 0.4549, 0.4588,  ..., 0.5412, 0.5490, 0.5529],
#           [0.4510, 0.4510, 0.4549,  ..., 0.5412, 0.5451, 0.5490],
#           ...,
#           [0.4784, 0.4784, 0.4784,  ..., 0.4235, 0.4000, 0.3882],
#           [0.4745, 0.4824, 0.4863,  ..., 0.4196, 0.3961, 0.3843],
#           [0.4667, 0.4784, 0.4902,  ..., 0.4235, 0.4000, 0.3843]],
#
#          [[0.4000, 0.3961, 0.4000,  ..., 0.4745, 0.4863, 0.4980],
#           [0.4000, 0.4000, 0.4039,  ..., 0.4706, 0.4824, 0.4941],
#           [0.3961, 0.3961, 0.4000,  ..., 0.4706, 0.4784, 0.4902],
#           ...,
#           [0.4078, 0.4078, 0.4078,  ..., 0.2431, 0.2039, 0.1765],
#           [0.4118, 0.4118, 0.4157,  ..., 0.2392, 0.2000, 0.1725],
#           [0.4078, 0.4157, 0.4275,  ..., 0.2353, 0.1961, 0.1686]]],
#
#
#         [[[0.4706, 0.4549, 0.4471,  ..., 0.2471, 0.1922, 0.2039],
#           [0.4235, 0.4196, 0.4118,  ..., 0.2275, 0.2078, 0.2118],
#           [0.4000, 0.3961, 0.3922,  ..., 0.2118, 0.2039, 0.2078],
#           ...,
#           [0.2667, 0.2157, 0.1137,  ..., 0.2549, 0.2471, 0.2392],
#           [0.2667, 0.2275, 0.1333,  ..., 0.2588, 0.2549, 0.2510],
#           [0.2627, 0.2471, 0.1686,  ..., 0.2549, 0.2627, 0.2588]],
#
#          [[0.5490, 0.5294, 0.5216,  ..., 0.2510, 0.2039, 0.2118],
#           [0.5020, 0.4863, 0.4745,  ..., 0.2275, 0.2157, 0.2196],
#           [0.4627, 0.4549, 0.4471,  ..., 0.2196, 0.2157, 0.2196],
#           ...,
#           [0.4510, 0.3725, 0.2353,  ..., 0.2275, 0.2157, 0.2039],
#           [0.4471, 0.3922, 0.2706,  ..., 0.2314, 0.2275, 0.2235],
#           [0.4392, 0.4118, 0.3059,  ..., 0.2353, 0.2353, 0.2314]],
#
#          [[0.5843, 0.5686, 0.5529,  ..., 0.1333, 0.1020, 0.1255],
#           [0.5294, 0.5176, 0.5059,  ..., 0.1176, 0.1216, 0.1373],
#           [0.4902, 0.4784, 0.4706,  ..., 0.1216, 0.1294, 0.1451],
#           ...,
#           [0.0824, 0.0627, 0.0314,  ..., 0.0627, 0.0588, 0.0588],
#           [0.0824, 0.0706, 0.0392,  ..., 0.0588, 0.0627, 0.0667],
#           [0.0745, 0.0784, 0.0510,  ..., 0.0627, 0.0706, 0.0667]]],
#
#
#         [[[0.3373, 0.3373, 0.3412,  ..., 0.3059, 0.3137, 0.2549],
#           [0.3255, 0.3412, 0.3490,  ..., 0.3176, 0.3216, 0.3098],
#           [0.3412, 0.3490, 0.3569,  ..., 0.3255, 0.3216, 0.3176],
#           ...,
#           [0.5451, 0.5647, 0.5608,  ..., 0.3373, 0.3451, 0.3412],
#           [0.5255, 0.5451, 0.5373,  ..., 0.3529, 0.3255, 0.3529],
#           [0.5098, 0.5294, 0.5569,  ..., 0.3255, 0.3451, 0.3569]],
#
#          [[0.3216, 0.3216, 0.3176,  ..., 0.3255, 0.3333, 0.2745],
#           [0.3059, 0.3255, 0.3255,  ..., 0.3373, 0.3412, 0.3294],
#           [0.3216, 0.3333, 0.3333,  ..., 0.3451, 0.3412, 0.3373],
#           ...,
#           [0.6118, 0.6235, 0.6078,  ..., 0.3451, 0.3451, 0.3412],
#           [0.5922, 0.6039, 0.5843,  ..., 0.3569, 0.3216, 0.3412],
#           [0.5843, 0.5961, 0.6118,  ..., 0.3255, 0.3333, 0.3373]],
#
#          [[0.3255, 0.3255, 0.3176,  ..., 0.3451, 0.3569, 0.2980],
#           [0.3216, 0.3294, 0.3333,  ..., 0.3529, 0.3647, 0.3529],
#           [0.3373, 0.3373, 0.3412,  ..., 0.3608, 0.3569, 0.3529],
#           ...,
#           [0.4863, 0.4941, 0.4745,  ..., 0.2941, 0.2980, 0.3098],
#           [0.4667, 0.4745, 0.4510,  ..., 0.3098, 0.2784, 0.3059],
#           [0.4588, 0.4627, 0.4745,  ..., 0.2941, 0.2980, 0.3137]]],
#
#
#         ...,
#
#
#         [[[0.4235, 0.4235, 0.4196,  ..., 0.3333, 0.3176, 0.3137],
#           [0.4235, 0.4235, 0.4196,  ..., 0.3451, 0.3333, 0.3294],
#           [0.4196, 0.4196, 0.4157,  ..., 0.3765, 0.3647, 0.3608],
#           ...,
#           [0.1608, 0.1647, 0.1686,  ..., 0.6392, 0.6353, 0.6353],
#           [0.1529, 0.1451, 0.1294,  ..., 0.6353, 0.6314, 0.6314],
#           [0.1490, 0.1373, 0.1098,  ..., 0.6314, 0.6275, 0.6275]],
#
#          [[0.5451, 0.5451, 0.5451,  ..., 0.1725, 0.1686, 0.1686],
#           [0.5451, 0.5451, 0.5451,  ..., 0.1804, 0.1765, 0.1765],
#           [0.5412, 0.5412, 0.5412,  ..., 0.1961, 0.1882, 0.1882],
#           ...,
#           [0.1569, 0.1569, 0.1569,  ..., 0.7569, 0.7608, 0.7608],
#           [0.1529, 0.1451, 0.1176,  ..., 0.7529, 0.7569, 0.7569],
#           [0.1490, 0.1373, 0.1020,  ..., 0.7529, 0.7569, 0.7569]],
#
#          [[0.3725, 0.3725, 0.3647,  ..., 0.2157, 0.2000, 0.1961],
#           [0.3725, 0.3725, 0.3647,  ..., 0.2275, 0.2118, 0.2078],
#           [0.3686, 0.3686, 0.3608,  ..., 0.2549, 0.2431, 0.2392],
#           ...,
#           [0.1137, 0.1137, 0.1176,  ..., 0.4000, 0.3961, 0.3961],
#           [0.1098, 0.1020, 0.0863,  ..., 0.4000, 0.4000, 0.4000],
#           [0.1098, 0.0980, 0.0706,  ..., 0.4000, 0.4000, 0.4000]]],
#
#
#         [[[0.4353, 0.4353, 0.4353,  ..., 0.2078, 0.2196, 0.2235],
#           [0.4353, 0.4353, 0.4353,  ..., 0.2078, 0.2196, 0.2235],
#           [0.4392, 0.4392, 0.4353,  ..., 0.2157, 0.2196, 0.2235],
#           ...,
#           [0.6353, 0.6039, 0.5490,  ..., 0.6745, 0.7529, 0.7961],
#           [0.6392, 0.6078, 0.5490,  ..., 0.5569, 0.6627, 0.7176],
#           [0.6392, 0.6078, 0.5490,  ..., 0.5294, 0.6392, 0.6980]],
#
#          [[0.3961, 0.3961, 0.3961,  ..., 0.1804, 0.1922, 0.1961],
#           [0.3961, 0.3961, 0.3961,  ..., 0.1804, 0.1922, 0.1961],
#           [0.4039, 0.4000, 0.4000,  ..., 0.1882, 0.1922, 0.1961],
#           ...,
#           [0.4431, 0.4157, 0.3569,  ..., 0.6118, 0.6941, 0.7333],
#           [0.4471, 0.4157, 0.3569,  ..., 0.4902, 0.5961, 0.6510],
#           [0.4471, 0.4157, 0.3569,  ..., 0.4627, 0.5725, 0.6314]],
#
#          [[0.4902, 0.4902, 0.4941,  ..., 0.2118, 0.2196, 0.2235],
#           [0.4902, 0.4902, 0.4941,  ..., 0.2118, 0.2196, 0.2235],
#           [0.4902, 0.4902, 0.4941,  ..., 0.2196, 0.2196, 0.2235],
#           ...,
#           [0.3804, 0.3529, 0.3059,  ..., 0.5804, 0.6627, 0.7020],
#           [0.3804, 0.3529, 0.3020,  ..., 0.4627, 0.5686, 0.6235],
#           [0.3804, 0.3529, 0.3020,  ..., 0.4353, 0.5451, 0.6039]]],
#
#
#         [[[0.6941, 0.7020, 0.7098,  ..., 0.7137, 0.7059, 0.7059],
#           [0.6902, 0.6941, 0.6980,  ..., 0.7137, 0.7059, 0.7059],
#           [0.6941, 0.6941, 0.6980,  ..., 0.7098, 0.7059, 0.7059],
#           ...,
#           [0.6745, 0.6588, 0.6392,  ..., 0.5961, 0.5804, 0.5804],
#           [0.5961, 0.6353, 0.6588,  ..., 0.5098, 0.5373, 0.6118],
#           [0.5451, 0.5020, 0.4824,  ..., 0.4902, 0.5098, 0.5529]],
#
#          [[0.5451, 0.5529, 0.5608,  ..., 0.5451, 0.5490, 0.5490],
#           [0.5529, 0.5569, 0.5608,  ..., 0.5451, 0.5490, 0.5490],
#           [0.5569, 0.5569, 0.5608,  ..., 0.5412, 0.5490, 0.5490],
#           ...,
#           [0.5412, 0.5255, 0.5098,  ..., 0.4627, 0.4510, 0.4510],
#           [0.4627, 0.5020, 0.5294,  ..., 0.3804, 0.4078, 0.4784],
#           [0.4157, 0.3725, 0.3529,  ..., 0.3608, 0.3725, 0.4157]],
#
#          [[0.3922, 0.4000, 0.4078,  ..., 0.4078, 0.4078, 0.4078],
#           [0.3961, 0.4000, 0.4039,  ..., 0.4078, 0.4078, 0.4078],
#           [0.4000, 0.4000, 0.4039,  ..., 0.4039, 0.4078, 0.4078],
#           ...,
#           [0.4039, 0.3882, 0.3804,  ..., 0.3529, 0.3294, 0.3294],
#           [0.3255, 0.3647, 0.3961,  ..., 0.2588, 0.2863, 0.3569],
#           [0.2863, 0.2431, 0.2235,  ..., 0.2314, 0.2471, 0.2902]]]]), Labels: tensor([355,  79, 455, 514, 330, 309, 448, 314, 300, 145, 140, 243,  16, 381,
#         375, 371, 448, 473, 405, 291, 476, 202, 170, 256, 423, 291,  79, 209,
#         378,  59, 142, 503])
# Batch 1 - Batch Size: 32

# %% [markdown]
#  # 2. Metrics

# %%
from sklearn import metrics as skmetrics
import numpy
class Metrics:
    def __init__(self, metric_names):
        self.metric_names = metric_names
        # initialize a metric dictionary
        self.metric_dict = {metric_name: [0] for metric_name in self.metric_names}

    def step(self, labels, preds):
        for metric in self.metric_names:
            # get the metric function
            do_metric = getattr(
                skmetrics, metric, "The metric {} is not implemented".format(metric)
            )
            # check if metric require average method, if yes set to 'micro' or 'macro' or 'None'
            try:
                self.metric_dict[metric].append(
                    do_metric(labels, preds, average="macro")
                )
            except:
                self.metric_dict[metric].append(do_metric(labels, preds))

    def epoch(self):
        # calculate metrics for an entire epoch
        avg = [sum(metric) / (len(metric) - 1) for metric in self.metric_dict.values()]
        metric_as_dict = dict(zip(self.metric_names, avg))
        return metric_as_dict

    def last_step_metrics(self):
        # return metrics of last steps
        values = [self.metric_dict[metric][-1] for metric in self.metric_names]
        metric_as_dict = dict(zip(self.metric_names, values))
        return metric_as_dict
    
train_metrics = Metrics(["accuracy_score","f1_score"])
valid_metrics = Metrics(["accuracy_score","f1_score"])

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.optim import lr_scheduler

class LabelSmoothingLoss(nn.Module):
    def __init__(self, smoothing=0.1, dim=-1):
        super(LabelSmoothingLoss, self).__init__()
        self.smoothing = smoothing
        self.dim = dim

    def forward(self, pred, target):
        target = F.one_hot(target, num_classes=pred.size(-1))
        target = target.float()
        target = (1 - self.smoothing) * target + self.smoothing / pred.size(-1)
        log_pred = F.log_softmax(pred, dim=self.dim)
        loss = nn.KLDivLoss(reduction='batchmean')(log_pred, target)
        return loss

# %% [markdown]
# # 3. Model EfficientNet-B4

# %%
# Chuyển mô hình và dữ liệu sang GPU nếu có sẵn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print (device)
# Out:
# cpu

# %%
# EfficientNet-B4 architecture from the torchvision library and modifying its classifier for transfer learning. 
# freezing the pre-trained weights of the base model and replacing the classifier with custom classifier.

# Download the weights manually
state_dict = torch.hub.load_state_dict_from_url("https://download.pytorch.org/models/efficientnet_b4_rwightman-7eb33cd5.pth")

# Create the model
model = models.efficientnet_b4(pretrained=True).to(device)

# Load the weights
model.load_state_dict(state_dict)

for param in model.parameters():
    param.requires_grad = False
    # freeze tất cả trọng số của model gốc
classifier = nn.Sequential(
    nn.Linear(in_features=model.classifier[1].in_features, out_features=256,bias=True),
    nn.Linear(in_features=256, out_features=525,bias=True)
)
model.classifier  = classifier


# Định nghĩa hàm loss và optimizer
#criterion = nn.CrossEntropyLoss()
criterion = LabelSmoothingLoss(smoothing=0.12)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Apply learning rate scheduling
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B4_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B4_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# Chuyển mô hình và dữ liệu sang GPU nếu có sẵn
import torch
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.distributed.xla_multiprocessing as xmp

try:
    # Connect to TPU
    device = xm.xla_device()
    print("Running on TPU")
except ImportError:
    print("TPU not available. Running on CPU/GPU.")
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


model.to(device)

model.load_state_dict(state_dict)

device
# Out:
# Running on TPU
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 18
#      13     device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      16 model.to(device)
# ---> 18 model.load_state_dict(state_dict)
#      20 device
#
# File /usr/local/lib/python3.10/site-packages/torch/nn/modules/module.py:2152, in Module.load_state_dict(self, state_dict, strict, assign)
#    2147         error_msgs.insert(
#    2148             0, 'Missing key(s) in state_dict: {}. '.format(
#    2149                 ', '.join(f'"{k}"' for k in missing_keys)))
#    2151 if len(error_msgs) > 0:
# -> 2152     raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    2153                        self.__class__.__name__, "\n\t".join(error_msgs)))
#    2154 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for EfficientNet:
# 	Missing key(s) in state_dict: "classifier.0.weight", "classifier.0.bias".
# 	size mismatch for classifier.1.weight: copying a param with shape torch.Size([1000, 1792]) from checkpoint, the shape in current model is torch.Size([525, 256]).
# 	size mismatch for classifier.1.bias: copying a param with shape torch.Size([1000]) from checkpoint, the shape in current model is torch.Size([525]).

# %% [markdown]
# # 4. Def Training Epoch

# %%
def train_one_epoch(
    model,
    train_loader,
    test_loader,
    device,
    optimizer,
    criterion,
    train_metrics,
    val_metrics,
):

    # training-the-model
    train_loss = 0
    valid_loss = 0
    all_labels = []
    all_preds = []
    model.train()
    for data, target in train_loader:
        # move-tensors-to-GPU
        data = data.type(torch.FloatTensor).to(device)
        # target=torch.Tensor(target)
        target = target.float().to(device)
        # clear-the-gradients-of-all-optimized-variables
        optimizer.zero_grad()
        # forward-pass: compute-predicted-outputs-by-passing-inputs-to-the-model
        output = model(data)
        # get the prediction label and target label
        output = model(data)
        preds = torch.argmax(output, axis=1).cpu().detach().numpy()
        labels = target.cpu().numpy()
        # calculate-the-batch-loss
        loss = criterion(output.type(torch.FloatTensor), target.type(torch.LongTensor))
        # backward-pass: compute-gradient-of-the-loss-wrt-model-parameters
        loss.backward()
        # perform-a-ingle-optimization-step (parameter-update)
        optimizer.step()
        # update-training-loss
        train_loss += loss.item() * data.size(0)
        # calculate training metrics
        all_labels.extend(labels)
        all_preds.extend(preds)
    
    train_metrics.step(all_labels, all_preds)

    # validate-the-model
    model.eval()
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for data, target in test_loader:
            data = data.type(torch.FloatTensor).to(device)
            target = target.to(device)
            output = model(data)
            preds = torch.argmax(output, axis=1).tolist()
            labels = target.tolist()
            all_labels.extend(labels)
            all_preds.extend(preds)
            loss = criterion(output, target)

            # update-average-validation-loss
            valid_loss += loss.item() * data.size(0)

    val_metrics.step(all_labels, all_preds)
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(test_loader.sampler)

    return (
        train_loss,
        valid_loss,
        train_metrics.last_step_metrics(),
        val_metrics.last_step_metrics(),
    )

# %% [markdown]
# # 5. Train model

# %%
import time
import logging
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## 5.1 First 10 epochs

# %%
start_time = time.time()
best_val_acc = 0
print("begin training process")
for i in tqdm(range(0, num_epochs)):
    loss, val_loss, train_result, val_result = train_one_epoch(
        model,
        train_loader,
        valid_loader,
        device,
        optimizer,
        criterion,
        train_metrics,
        valid_metrics,
    )

    scheduler.step(val_loss)
    
    print("Epoch {} / {} \n Training loss: {} - Other training metrics: ".format(i + 1, num_epochs, loss))
    print(train_result)
    print(" \n Validation loss : {} - Other validation metrics:".format(val_loss))
    print(val_result)
    print("\n")
    
    # saving epoch with best validation accuracy
    if best_val_acc < float(val_result["accuracy_score"]):
        print("Validation accuracy= "+ str(val_result["accuracy_score"])+ "===> Save best epoch")
        best_val_acc = val_result["accuracy_score"]
        torch.save(model.state_dict(),"./" +  "best.pt",)
    else:
        print("Validation accuracy= "+ str(val_result["accuracy_score"])+ "===> No saving")
        continue

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Total runtime first 10 epoch : {elapsed_time} seconds")

# %% [markdown]
# ## 5.2 Next 10 epochs

# %%
for param in model.parameters():
    param.requires_grad = True
    
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

start_time = time.time()
model = model.to(device)
best_val_acc = 0.8528
import logging
import numpy as np
print("begin training process")
for i in tqdm(range(0, num_epochs)):
    loss, val_loss, train_result, val_result = train_one_epoch(
        model,
        train_loader,
        valid_loader,
        device,
        optimizer,
        criterion,
        train_metrics,
        valid_metrics,
    )

    scheduler.step(val_loss)
    print("Epoch {} / {} \n Training loss: {} - Other training metrics: ".format(i + 1, num_epochs, loss))
    print(train_result)
    print(" \n Validation loss : {} - Other validation metrics:".format(val_loss))
    print(val_result)
    print("\n")
    
    # saving epoch with best validation accuracy
    if best_val_acc < float(val_result["accuracy_score"]):
        print("Validation accuracy= "+ str(val_result["accuracy_score"])+ "===> Save best epoch")
        best_val_acc = val_result["accuracy_score"]
        torch.save(model, "./" +  "best.pt")
    else:
        print("Validation accuracy= "+ str(val_result["accuracy_score"])+ "===> No saving")
        continue
        
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Total runtime next 10 epoch : {elapsed_time} seconds")

# %% [markdown]
# ## 2. Tuning mô hình sử dụng các kỹ thuật đã học. Report lại performance trên tập Val và Test. Nhận xét kết quả thu được

# %% [markdown]
# In summary, **lr_scheduler.StepLR** is suitable for a fixed schedule of learning rate reductions, while **torch.optim.lr_scheduler.ReduceLROnPlateau** is more adaptive and changes the learning rate based on the model's performance.
#
# => can try this scheduler for further tunning.

# %%
test_model = torch.load("/kaggle/working/best.pt")
test_model = test_model.to(device)

# %%
def test_result(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    preds, labels = [], []

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)

            # Forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)

            # Applying Softmax to the results
            probs = nn.Softmax(dim=1)(output)

            labels.extend(target.tolist())
            preds.extend(torch.argmax(probs, axis=1).tolist())

    return labels, preds

# %%
# Display confusion matrix and classification report for the test set
labels_test, preds_test = test_result(model, test_loader, device)
report_test = classification_report(labels_test, preds_test, digits=4, target_names=train_dataset.classes)

cm_test = confusion_matrix(labels_test, preds_test)
print(report_test)

# %%
# Plotting the training and validation losses
plt.plot(train_losses, label='Training Loss')
plt.plot(valid_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Display confusion matrix
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=train_dataset.classes)
disp_test.plot()

# %%
# Evaluate the model on the test set
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = test_correct / test_total
print(f"Test Accuracy: {test_accuracy:.4f}")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets, models
from sklearn.model_selection import train_test_split

# Thiết lập các tham số
batch_size = 32
learning_rate = 0.001
num_epochs = 10

# Đường dẫn đến tập dữ liệu
data_dir = "/kaggle/input/100-bird-species/"

# Áp dụng các biến đổi cho dữ liệu huấn luyện và kiểm thử
transform_train = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# Tạo DataLoader cho dữ liệu huấn luyện và kiểm thử 
# ImageFolder => label encoder already included
train_dataset = datasets.ImageFolder(root=data_dir + 'train', transform=transform_train)
test_dataset = datasets.ImageFolder(root=data_dir + 'test', transform=transform_test)
valid_dataset = datasets.ImageFolder(root=data_dir + 'valid', transform=transform_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

# Số lượng mẫu
len(train_dataset)

# Print all the classes
classes = train_dataset.classes
print("Len of train Classes:",len(classes))
print("Len of test Classes:",len(test_dataset.classes))

# Get the class-to-index mapping
class_to_idx = train_dataset.class_to_idx

# Print classes with their indices
for class_name, class_idx in class_to_idx.items():
    print(f"Class: {class_name}, Index: {class_idx}")
    
# In input và labels của batch đầu tiên
for batch_idx, (inputs, labels) in enumerate(train_loader):
    # Print the current batch
    print(f"Batch {batch_idx + 1} - Inputs: {inputs}, Labels: {labels}")

    # Print the size of the current batch (number of samples in the batch)
    print(f"Batch {batch_idx + 1} - Batch Size: {len(inputs)}")

    # Break after printing the first 5 batches
    if batch_idx == 0:
        break
        
from sklearn import metrics as skmetrics
import numpy
class Metrics:
    def __init__(self, metric_names):
        self.metric_names = metric_names
        # initialize a metric dictionary
        self.metric_dict = {metric_name: [0] for metric_name in self.metric_names}

    def step(self, labels, preds):
        for metric in self.metric_names:
            # get the metric function
            do_metric = getattr(
                skmetrics, metric, "The metric {} is not implemented".format(metric)
            )
            # check if metric require average method, if yes set to 'micro' or 'macro' or 'None'
            try:
                self.metric_dict[metric].append(
                    do_metric(labels, preds, average="macro")
                )
            except:
                self.metric_dict[metric].append(do_metric(labels, preds))

    def epoch(self):
        # calculate metrics for an entire epoch
        avg = [sum(metric) / (len(metric) - 1) for metric in self.metric_dict.values()]
        metric_as_dict = dict(zip(self.metric_names, avg))
        return metric_as_dict

    def last_step_metrics(self):
        # return metrics of last steps
        values = [self.metric_dict[metric][-1] for metric in self.metric_names]
        metric_as_dict = dict(zip(self.metric_names, values))
        return metric_as_dict
    
train_metrics = Metrics(["accuracy_score","f1_score"])
valid_metrics = Metrics(["accuracy_score","f1_score"])

import torch
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.optim import lr_scheduler

class LabelSmoothingLoss(nn.Module):
    def __init__(self, smoothing=0.1, dim=-1):
        super(LabelSmoothingLoss, self).__init__()
        self.smoothing = smoothing
        self.dim = dim

    def forward(self, pred, target):
        target = F.one_hot(target, num_classes=pred.size(-1))
        target = target.float()
        target = (1 - self.smoothing) * target + self.smoothing / pred.size(-1)
        log_pred = F.log_softmax(pred, dim=self.dim)
        loss = nn.KLDivLoss(reduction='batchmean')(log_pred, target)
        return loss
        
# Chuyển mô hình và dữ liệu sang GPU nếu có sẵn
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print (device)

# EfficientNet-B4 architecture from the torchvision library and modifying its classifier for transfer learning. 
# freezing the pre-trained weights of the base model and replacing the classifier with custom classifier.

# Download the weights manually
state_dict = torch.hub.load_state_dict_from_url("https://download.pytorch.org/models/efficientnet_b4_rwightman-7eb33cd5.pth")

# Create the model
model = models.efficientnet_b4(pretrained=True).to(device)

# Load the weights
model.load_state_dict(state_dict)

for param in model.parameters():
    param.requires_grad = False
    # freeze tất cả trọng số của model gốc
classifier = nn.Sequential(
    nn.Linear(in_features=model.classifier[1].in_features, out_features=256,bias=True),
    nn.Linear(in_features=256, out_features=525,bias=True)
)
model.classifier  = classifier


# Định nghĩa hàm loss và optimizer
#criterion = nn.CrossEntropyLoss()
criterion = LabelSmoothingLoss(smoothing=0.12)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Apply learning rate scheduling
scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# Len of train Classes: 525
# Len of test Classes: 525
# Class: ABBOTTS BABBLER, Index: 0
# Class: ABBOTTS BOOBY, Index: 1
# Class: ABYSSINIAN GROUND HORNBILL, Index: 2
# Class: AFRICAN CROWNED CRANE, Index: 3
# Class: AFRICAN EMERALD CUCKOO, Index: 4
# Class: AFRICAN FIREFINCH, Index: 5
# Class: AFRICAN OYSTER CATCHER, Index: 6
# Class: AFRICAN PIED HORNBILL, Index: 7
# Class: AFRICAN PYGMY GOOSE, Index: 8
# Class: ALBATROSS, Index: 9
# Class: ALBERTS TOWHEE, Index: 10
# Class: ALEXANDRINE PARAKEET, Index: 11
# Class: ALPINE CHOUGH, Index: 12
# Class: ALTAMIRA YELLOWTHROAT, Index: 13
# Class: AMERICAN AVOCET, Index: 14
# Class: AMERICAN BITTERN, Index: 15
# Class: AMERICAN COOT, Index: 16
# Class: AMERICAN DIPPER, Index: 17
# Class: AMERICAN FLAMINGO, Index: 18
# Class: AMERICAN GOLDFINCH, Index: 19
# Class: AMERICAN KESTREL, Index: 20
# Class: AMERICAN PIPIT, Index: 21
# Class: AMERICAN REDSTART, Index: 22
# Class: AMERICAN ROBIN, Index: 23
# Class: AMERICAN WIGEON, Index: 24
# Class: AMETHYST WOODSTAR, Index: 25
# Class: ANDEAN GOOSE, Index: 26
# Class: ANDEAN LAPWING, Index: 27
# Class: ANDEAN SISKIN, Index: 28
# Class: ANHINGA, Index: 29
# Class: ANIANIAU, Index: 30
# Class: ANNAS HUMMINGBIRD, Index: 31
# Class: ANTBIRD, Index: 32
# Class: ANTILLEAN EUPHONIA, Index: 33
# Class: APAPANE, Index: 34
# Class: APOSTLEBIRD, Index: 35
# Class: ARARIPE MANAKIN, Index: 36
# Class: ASHY STORM PETREL, Index: 37
# Class: ASHY THRUSHBIRD, Index: 38
# Class: ASIAN CRESTED IBIS, Index: 39
# Class: ASIAN DOLLARD BIRD, Index: 40
# Class: ASIAN GREEN BEE EATER, Index: 41
# Class: ASIAN OPENBILL STORK, Index: 42
# Class: AUCKLAND SHAQ, Index: 43
# Class: AUSTRAL CANASTERO, Index: 44
# Class: AUSTRALASIAN FIGBIRD, Index: 45
# Class: AVADAVAT, Index: 46
# Class: AZARAS SPINETAIL, Index: 47
# Class: AZURE BREASTED PITTA, Index: 48
# Class: AZURE JAY, Index: 49
# Class: AZURE TANAGER, Index: 50
# Class: AZURE TIT, Index: 51
# Class: BAIKAL TEAL, Index: 52
# Class: BALD EAGLE, Index: 53
# Class: BALD IBIS, Index: 54
# Class: BALI STARLING, Index: 55
# Class: BALTIMORE ORIOLE, Index: 56
# Class: BANANAQUIT, Index: 57
# Class: BAND TAILED GUAN, Index: 58
# Class: BANDED BROADBILL, Index: 59
# Class: BANDED PITA, Index: 60
# Class: BANDED STILT, Index: 61
# Class: BAR-TAILED GODWIT, Index: 62
# Class: BARN OWL, Index: 63
# Class: BARN SWALLOW, Index: 64
# Class: BARRED PUFFBIRD, Index: 65
# Class: BARROWS GOLDENEYE, Index: 66
# Class: BAY-BREASTED WARBLER, Index: 67
# Class: BEARDED BARBET, Index: 68
# Class: BEARDED BELLBIRD, Index: 69
# Class: BEARDED REEDLING, Index: 70
# Class: BELTED KINGFISHER, Index: 71
# Class: BIRD OF PARADISE, Index: 72
# Class: BLACK AND YELLOW BROADBILL, Index: 73
# Class: BLACK BAZA, Index: 74
# Class: BLACK BREASTED PUFFBIRD, Index: 75
# Class: BLACK COCKATO, Index: 76
# Class: BLACK FACED SPOONBILL, Index: 77
# Class: BLACK FRANCOLIN, Index: 78
# Class: BLACK HEADED CAIQUE, Index: 79
# Class: BLACK NECKED STILT, Index: 80
# Class: BLACK SKIMMER, Index: 81
# Class: BLACK SWAN, Index: 82
# Class: BLACK TAIL CRAKE, Index: 83
# Class: BLACK THROATED BUSHTIT, Index: 84
# Class: BLACK THROATED HUET, Index: 85
# Class: BLACK THROATED WARBLER, Index: 86
# Class: BLACK VENTED SHEARWATER, Index: 87
# Class: BLACK VULTURE, Index: 88
# Class: BLACK-CAPPED CHICKADEE, Index: 89
# Class: BLACK-NECKED GREBE, Index: 90
# Class: BLACK-THROATED SPARROW, Index: 91
# Class: BLACKBURNIAM WARBLER, Index: 92
# Class: BLONDE CRESTED WOODPECKER, Index: 93
# Class: BLOOD PHEASANT, Index: 94
# Class: BLUE COAU, Index: 95
# Class: BLUE DACNIS, Index: 96
# Class: BLUE GRAY GNATCATCHER, Index: 97
# Class: BLUE GROSBEAK, Index: 98
# Class: BLUE GROUSE, Index: 99
# Class: BLUE HERON, Index: 100
# Class: BLUE MALKOHA, Index: 101
# Class: BLUE THROATED PIPING GUAN, Index: 102
# Class: BLUE THROATED TOUCANET, Index: 103
# Class: BOBOLINK, Index: 104
# Class: BORNEAN BRISTLEHEAD, Index: 105
# Class: BORNEAN LEAFBIRD, Index: 106
# Class: BORNEAN PHEASANT, Index: 107
# Class: BRANDT CORMARANT, Index: 108
# Class: BREWERS BLACKBIRD, Index: 109
# Class: BROWN CREPPER, Index: 110
# Class: BROWN HEADED COWBIRD, Index: 111
# Class: BROWN NOODY, Index: 112
# Class: BROWN THRASHER, Index: 113
# Class: BUFFLEHEAD, Index: 114
# Class: BULWERS PHEASANT, Index: 115
# Class: BURCHELLS COURSER, Index: 116
# Class: BUSH TURKEY, Index: 117
# Class: CAATINGA CACHOLOTE, Index: 118
# Class: CABOTS TRAGOPAN, Index: 119
# Class: CACTUS WREN, Index: 120
# Class: CALIFORNIA CONDOR, Index: 121
# Class: CALIFORNIA GULL, Index: 122
# Class: CALIFORNIA QUAIL, Index: 123
# Class: CAMPO FLICKER, Index: 124
# Class: CANARY, Index: 125
# Class: CANVASBACK, Index: 126
# Class: CAPE GLOSSY STARLING, Index: 127
# Class: CAPE LONGCLAW, Index: 128
# Class: CAPE MAY WARBLER, Index: 129
# Class: CAPE ROCK THRUSH, Index: 130
# Class: CAPPED HERON, Index: 131
# Class: CAPUCHINBIRD, Index: 132
# Class: CARMINE BEE-EATER, Index: 133
# Class: CASPIAN TERN, Index: 134
# Class: CASSOWARY, Index: 135
# Class: CEDAR WAXWING, Index: 136
# Class: CERULEAN WARBLER, Index: 137
# Class: CHARA DE COLLAR, Index: 138
# Class: CHATTERING LORY, Index: 139
# Class: CHESTNET BELLIED EUPHONIA, Index: 140
# Class: CHESTNUT WINGED CUCKOO, Index: 141
# Class: CHINESE BAMBOO PARTRIDGE, Index: 142
# Class: CHINESE POND HERON, Index: 143
# Class: CHIPPING SPARROW, Index: 144
# Class: CHUCAO TAPACULO, Index: 145
# Class: CHUKAR PARTRIDGE, Index: 146
# Class: CINNAMON ATTILA, Index: 147
# Class: CINNAMON FLYCATCHER, Index: 148
# Class: CINNAMON TEAL, Index: 149
# Class: CLARKS GREBE, Index: 150
# Class: CLARKS NUTCRACKER, Index: 151
# Class: COCK OF THE  ROCK, Index: 152
# Class: COCKATOO, Index: 153
# Class: COLLARED ARACARI, Index: 154
# Class: COLLARED CRESCENTCHEST, Index: 155
# Class: COMMON FIRECREST, Index: 156
# Class: COMMON GRACKLE, Index: 157
# Class: COMMON HOUSE MARTIN, Index: 158
# Class: COMMON IORA, Index: 159
# Class: COMMON LOON, Index: 160
# Class: COMMON POORWILL, Index: 161
# Class: COMMON STARLING, Index: 162
# Class: COPPERSMITH BARBET, Index: 163
# Class: COPPERY TAILED COUCAL, Index: 164
# Class: CRAB PLOVER, Index: 165
# Class: CRANE HAWK, Index: 166
# Class: CREAM COLORED WOODPECKER, Index: 167
# Class: CRESTED AUKLET, Index: 168
# Class: CRESTED CARACARA, Index: 169
# Class: CRESTED COUA, Index: 170
# Class: CRESTED FIREBACK, Index: 171
# Class: CRESTED KINGFISHER, Index: 172
# Class: CRESTED NUTHATCH, Index: 173
# Class: CRESTED OROPENDOLA, Index: 174
# Class: CRESTED SERPENT EAGLE, Index: 175
# Class: CRESTED SHRIKETIT, Index: 176
# Class: CRESTED WOOD PARTRIDGE, Index: 177
# Class: CRIMSON CHAT, Index: 178
# Class: CRIMSON SUNBIRD, Index: 179
# Class: CROW, Index: 180
# Class: CUBAN TODY, Index: 181
# Class: CUBAN TROGON, Index: 182
# Class: CURL CRESTED ARACURI, Index: 183
# Class: D-ARNAUDS BARBET, Index: 184
# Class: DALMATIAN PELICAN, Index: 185
# Class: DARJEELING WOODPECKER, Index: 186
# Class: DARK EYED JUNCO, Index: 187
# Class: DAURIAN REDSTART, Index: 188
# Class: DEMOISELLE CRANE, Index: 189
# Class: DOUBLE BARRED FINCH, Index: 190
# Class: DOUBLE BRESTED CORMARANT, Index: 191
# Class: DOUBLE EYED FIG PARROT, Index: 192
# Class: DOWNY WOODPECKER, Index: 193
# Class: DUNLIN, Index: 194
# Class: DUSKY LORY, Index: 195
# Class: DUSKY ROBIN, Index: 196
# Class: EARED PITA, Index: 197
# Class: EASTERN BLUEBIRD, Index: 198
# Class: EASTERN BLUEBONNET, Index: 199
# Class: EASTERN GOLDEN WEAVER, Index: 200
# Class: EASTERN MEADOWLARK, Index: 201
# Class: EASTERN ROSELLA, Index: 202
# Class: EASTERN TOWEE, Index: 203
# Class: EASTERN WIP POOR WILL, Index: 204
# Class: EASTERN YELLOW ROBIN, Index: 205
# Class: ECUADORIAN HILLSTAR, Index: 206
# Class: EGYPTIAN GOOSE, Index: 207
# Class: ELEGANT TROGON, Index: 208
# Class: ELLIOTS  PHEASANT, Index: 209
# Class: EMERALD TANAGER, Index: 210
# Class: EMPEROR PENGUIN, Index: 211
# Class: EMU, Index: 212
# Class: ENGGANO MYNA, Index: 213
# Class: EURASIAN BULLFINCH, Index: 214
# Class: EURASIAN GOLDEN ORIOLE, Index: 215
# Class: EURASIAN MAGPIE, Index: 216
# Class: EUROPEAN GOLDFINCH, Index: 217
# Class: EUROPEAN TURTLE DOVE, Index: 218
# Class: EVENING GROSBEAK, Index: 219
# Class: FAIRY BLUEBIRD, Index: 220
# Class: FAIRY PENGUIN, Index: 221
# Class: FAIRY TERN, Index: 222
# Class: FAN TAILED WIDOW, Index: 223
# Class: FASCIATED WREN, Index: 224
# Class: FIERY MINIVET, Index: 225
# Class: FIORDLAND PENGUIN, Index: 226
# Class: FIRE TAILLED MYZORNIS, Index: 227
# Class: FLAME BOWERBIRD, Index: 228
# Class: FLAME TANAGER, Index: 229
# Class: FOREST WAGTAIL, Index: 230
# Class: FRIGATE, Index: 231
# Class: FRILL BACK PIGEON, Index: 232
# Class: GAMBELS QUAIL, Index: 233
# Class: GANG GANG COCKATOO, Index: 234
# Class: GILA WOODPECKER, Index: 235
# Class: GILDED FLICKER, Index: 236
# Class: GLOSSY IBIS, Index: 237
# Class: GO AWAY BIRD, Index: 238
# Class: GOLD WING WARBLER, Index: 239
# Class: GOLDEN BOWER BIRD, Index: 240
# Class: GOLDEN CHEEKED WARBLER, Index: 241
# Class: GOLDEN CHLOROPHONIA, Index: 242
# Class: GOLDEN EAGLE, Index: 243
# Class: GOLDEN PARAKEET, Index: 244
# Class: GOLDEN PHEASANT, Index: 245
# Class: GOLDEN PIPIT, Index: 246
# Class: GOULDIAN FINCH, Index: 247
# Class: GRANDALA, Index: 248
# Class: GRAY CATBIRD, Index: 249
# Class: GRAY KINGBIRD, Index: 250
# Class: GRAY PARTRIDGE, Index: 251
# Class: GREAT ARGUS, Index: 252
# Class: GREAT GRAY OWL, Index: 253
# Class: GREAT JACAMAR, Index: 254
# Class: GREAT KISKADEE, Index: 255
# Class: GREAT POTOO, Index: 256
# Class: GREAT TINAMOU, Index: 257
# Class: GREAT XENOPS, Index: 258
# Class: GREATER PEWEE, Index: 259
# Class: GREATER PRAIRIE CHICKEN, Index: 260
# Class: GREATOR SAGE GROUSE, Index: 261
# Class: GREEN BROADBILL, Index: 262
# Class: GREEN JAY, Index: 263
# Class: GREEN MAGPIE, Index: 264
# Class: GREEN WINGED DOVE, Index: 265
# Class: GREY CUCKOOSHRIKE, Index: 266
# Class: GREY HEADED CHACHALACA, Index: 267
# Class: GREY HEADED FISH EAGLE, Index: 268
# Class: GREY PLOVER, Index: 269
# Class: GROVED BILLED ANI, Index: 270
# Class: GUINEA TURACO, Index: 271
# Class: GUINEAFOWL, Index: 272
# Class: GURNEYS PITTA, Index: 273
# Class: GYRFALCON, Index: 274
# Class: HAMERKOP, Index: 275
# Class: HARLEQUIN DUCK, Index: 276
# Class: HARLEQUIN QUAIL, Index: 277
# Class: HARPY EAGLE, Index: 278
# Class: HAWAIIAN GOOSE, Index: 279
# Class: HAWFINCH, Index: 280
# Class: HELMET VANGA, Index: 281
# Class: HEPATIC TANAGER, Index: 282
# Class: HIMALAYAN BLUETAIL, Index: 283
# Class: HIMALAYAN MONAL, Index: 284
# Class: HOATZIN, Index: 285
# Class: HOODED MERGANSER, Index: 286
# Class: HOOPOES, Index: 287
# Class: HORNED GUAN, Index: 288
# Class: HORNED LARK, Index: 289
# Class: HORNED SUNGEM, Index: 290
# Class: HOUSE FINCH, Index: 291
# Class: HOUSE SPARROW, Index: 292
# Class: HYACINTH MACAW, Index: 293
# Class: IBERIAN MAGPIE, Index: 294
# Class: IBISBILL, Index: 295
# Class: IMPERIAL SHAQ, Index: 296
# Class: INCA TERN, Index: 297
# Class: INDIAN BUSTARD, Index: 298
# Class: INDIAN PITTA, Index: 299
# Class: INDIAN ROLLER, Index: 300
# Class: INDIAN VULTURE, Index: 301
# Class: INDIGO BUNTING, Index: 302
# Class: INDIGO FLYCATCHER, Index: 303
# Class: INLAND DOTTEREL, Index: 304
# Class: IVORY BILLED ARACARI, Index: 305
# Class: IVORY GULL, Index: 306
# Class: IWI, Index: 307
# Class: JABIRU, Index: 308
# Class: JACK SNIPE, Index: 309
# Class: JACOBIN PIGEON, Index: 310
# Class: JANDAYA PARAKEET, Index: 311
# Class: JAPANESE ROBIN, Index: 312
# Class: JAVA SPARROW, Index: 313
# Class: JOCOTOCO ANTPITTA, Index: 314
# Class: KAGU, Index: 315
# Class: KAKAPO, Index: 316
# Class: KILLDEAR, Index: 317
# Class: KING EIDER, Index: 318
# Class: KING VULTURE, Index: 319
# Class: KIWI, Index: 320
# Class: KNOB BILLED DUCK, Index: 321
# Class: KOOKABURRA, Index: 322
# Class: LARK BUNTING, Index: 323
# Class: LAUGHING GULL, Index: 324
# Class: LAZULI BUNTING, Index: 325
# Class: LESSER ADJUTANT, Index: 326
# Class: LILAC ROLLER, Index: 327
# Class: LIMPKIN, Index: 328
# Class: LITTLE AUK, Index: 329
# Class: LOGGERHEAD SHRIKE, Index: 330
# Class: LONG-EARED OWL, Index: 331
# Class: LOONEY BIRDS, Index: 332
# Class: LUCIFER HUMMINGBIRD, Index: 333
# Class: MAGPIE GOOSE, Index: 334
# Class: MALABAR HORNBILL, Index: 335
# Class: MALACHITE KINGFISHER, Index: 336
# Class: MALAGASY WHITE EYE, Index: 337
# Class: MALEO, Index: 338
# Class: MALLARD DUCK, Index: 339
# Class: MANDRIN DUCK, Index: 340
# Class: MANGROVE CUCKOO, Index: 341
# Class: MARABOU STORK, Index: 342
# Class: MASKED BOBWHITE, Index: 343
# Class: MASKED BOOBY, Index: 344
# Class: MASKED LAPWING, Index: 345
# Class: MCKAYS BUNTING, Index: 346
# Class: MERLIN, Index: 347
# Class: MIKADO  PHEASANT, Index: 348
# Class: MILITARY MACAW, Index: 349
# Class: MOURNING DOVE, Index: 350
# Class: MYNA, Index: 351
# Class: NICOBAR PIGEON, Index: 352
# Class: NOISY FRIARBIRD, Index: 353
# Class: NORTHERN BEARDLESS TYRANNULET, Index: 354
# Class: NORTHERN CARDINAL, Index: 355
# Class: NORTHERN FLICKER, Index: 356
# Class: NORTHERN FULMAR, Index: 357
# Class: NORTHERN GANNET, Index: 358
# Class: NORTHERN GOSHAWK, Index: 359
# Class: NORTHERN JACANA, Index: 360
# Class: NORTHERN MOCKINGBIRD, Index: 361
# Class: NORTHERN PARULA, Index: 362
# Class: NORTHERN RED BISHOP, Index: 363
# Class: NORTHERN SHOVELER, Index: 364
# Class: OCELLATED TURKEY, Index: 365
# Class: OILBIRD, Index: 366
# Class: OKINAWA RAIL, Index: 367
# Class: ORANGE BREASTED TROGON, Index: 368
# Class: ORANGE BRESTED BUNTING, Index: 369
# Class: ORIENTAL BAY OWL, Index: 370
# Class: ORNATE HAWK EAGLE, Index: 371
# Class: OSPREY, Index: 372
# Class: OSTRICH, Index: 373
# Class: OVENBIRD, Index: 374
# Class: OYSTER CATCHER, Index: 375
# Class: PAINTED BUNTING, Index: 376
# Class: PALILA, Index: 377
# Class: PALM NUT VULTURE, Index: 378
# Class: PARADISE TANAGER, Index: 379
# Class: PARAKETT  AUKLET, Index: 380
# Class: PARUS MAJOR, Index: 381
# Class: PATAGONIAN SIERRA FINCH, Index: 382
# Class: PEACOCK, Index: 383
# Class: PEREGRINE FALCON, Index: 384
# Class: PHAINOPEPLA, Index: 385
# Class: PHILIPPINE EAGLE, Index: 386
# Class: PINK ROBIN, Index: 387
# Class: PLUSH CRESTED JAY, Index: 388
# Class: POMARINE JAEGER, Index: 389
# Class: PUFFIN, Index: 390
# Class: PUNA TEAL, Index: 391
# Class: PURPLE FINCH, Index: 392
# Class: PURPLE GALLINULE, Index: 393
# Class: PURPLE MARTIN, Index: 394
# Class: PURPLE SWAMPHEN, Index: 395
# Class: PYGMY KINGFISHER, Index: 396
# Class: PYRRHULOXIA, Index: 397
# Class: QUETZAL, Index: 398
# Class: RAINBOW LORIKEET, Index: 399
# Class: RAZORBILL, Index: 400
# Class: RED BEARDED BEE EATER, Index: 401
# Class: RED BELLIED PITTA, Index: 402
# Class: RED BILLED TROPICBIRD, Index: 403
# Class: RED BROWED FINCH, Index: 404
# Class: RED CROSSBILL, Index: 405
# Class: RED FACED CORMORANT, Index: 406
# Class: RED FACED WARBLER, Index: 407
# Class: RED FODY, Index: 408
# Class: RED HEADED DUCK, Index: 409
# Class: RED HEADED WOODPECKER, Index: 410
# Class: RED KNOT, Index: 411
# Class: RED LEGGED HONEYCREEPER, Index: 412
# Class: RED NAPED TROGON, Index: 413
# Class: RED SHOULDERED HAWK, Index: 414
# Class: RED TAILED HAWK, Index: 415
# Class: RED TAILED THRUSH, Index: 416
# Class: RED WINGED BLACKBIRD, Index: 417
# Class: RED WISKERED BULBUL, Index: 418
# Class: REGENT BOWERBIRD, Index: 419
# Class: RING-NECKED PHEASANT, Index: 420
# Class: ROADRUNNER, Index: 421
# Class: ROCK DOVE, Index: 422
# Class: ROSE BREASTED COCKATOO, Index: 423
# Class: ROSE BREASTED GROSBEAK, Index: 424
# Class: ROSEATE SPOONBILL, Index: 425
# Class: ROSY FACED LOVEBIRD, Index: 426
# Class: ROUGH LEG BUZZARD, Index: 427
# Class: ROYAL FLYCATCHER, Index: 428
# Class: RUBY CROWNED KINGLET, Index: 429
# Class: RUBY THROATED HUMMINGBIRD, Index: 430
# Class: RUDDY SHELDUCK, Index: 431
# Class: RUDY KINGFISHER, Index: 432
# Class: RUFOUS KINGFISHER, Index: 433
# Class: RUFOUS TREPE, Index: 434
# Class: RUFUOS MOTMOT, Index: 435
# Class: SAMATRAN THRUSH, Index: 436
# Class: SAND MARTIN, Index: 437
# Class: SANDHILL CRANE, Index: 438
# Class: SATYR TRAGOPAN, Index: 439
# Class: SAYS PHOEBE, Index: 440
# Class: SCARLET CROWNED FRUIT DOVE, Index: 441
# Class: SCARLET FACED LIOCICHLA, Index: 442
# Class: SCARLET IBIS, Index: 443
# Class: SCARLET MACAW, Index: 444
# Class: SCARLET TANAGER, Index: 445
# Class: SHOEBILL, Index: 446
# Class: SHORT BILLED DOWITCHER, Index: 447
# Class: SMITHS LONGSPUR, Index: 448
# Class: SNOW GOOSE, Index: 449
# Class: SNOW PARTRIDGE, Index: 450
# Class: SNOWY EGRET, Index: 451
# Class: SNOWY OWL, Index: 452
# Class: SNOWY PLOVER, Index: 453
# Class: SNOWY SHEATHBILL, Index: 454
# Class: SORA, Index: 455
# Class: SPANGLED COTINGA, Index: 456
# Class: SPLENDID WREN, Index: 457
# Class: SPOON BILED SANDPIPER, Index: 458
# Class: SPOTTED CATBIRD, Index: 459
# Class: SPOTTED WHISTLING DUCK, Index: 460
# Class: SQUACCO HERON, Index: 461
# Class: SRI LANKA BLUE MAGPIE, Index: 462
# Class: STEAMER DUCK, Index: 463
# Class: STORK BILLED KINGFISHER, Index: 464
# Class: STRIATED CARACARA, Index: 465
# Class: STRIPED OWL, Index: 466
# Class: STRIPPED MANAKIN, Index: 467
# Class: STRIPPED SWALLOW, Index: 468
# Class: SUNBITTERN, Index: 469
# Class: SUPERB STARLING, Index: 470
# Class: SURF SCOTER, Index: 471
# Class: SWINHOES PHEASANT, Index: 472
# Class: TAILORBIRD, Index: 473
# Class: TAIWAN MAGPIE, Index: 474
# Class: TAKAHE, Index: 475
# Class: TASMANIAN HEN, Index: 476
# Class: TAWNY FROGMOUTH, Index: 477
# Class: TEAL DUCK, Index: 478
# Class: TIT MOUSE, Index: 479
# Class: TOUCHAN, Index: 480
# Class: TOWNSENDS WARBLER, Index: 481
# Class: TREE SWALLOW, Index: 482
# Class: TRICOLORED BLACKBIRD, Index: 483
# Class: TROPICAL KINGBIRD, Index: 484
# Class: TRUMPTER SWAN, Index: 485
# Class: TURKEY VULTURE, Index: 486
# Class: TURQUOISE MOTMOT, Index: 487
# Class: UMBRELLA BIRD, Index: 488
# Class: VARIED THRUSH, Index: 489
# Class: VEERY, Index: 490
# Class: VENEZUELIAN TROUPIAL, Index: 491
# Class: VERDIN, Index: 492
# Class: VERMILION FLYCATHER, Index: 493
# Class: VICTORIA CROWNED PIGEON, Index: 494
# Class: VIOLET BACKED STARLING, Index: 495
# Class: VIOLET CUCKOO, Index: 496
# Class: VIOLET GREEN SWALLOW, Index: 497
# Class: VIOLET TURACO, Index: 498
# Class: VISAYAN HORNBILL, Index: 499
# Class: VULTURINE GUINEAFOWL, Index: 500
# Class: WALL CREAPER, Index: 501
# Class: WATTLED CURASSOW, Index: 502
# Class: WATTLED LAPWING, Index: 503
# Class: WHIMBREL, Index: 504
# Class: WHITE BREASTED WATERHEN, Index: 505
# Class: WHITE BROWED CRAKE, Index: 506
# Class: WHITE CHEEKED TURACO, Index: 507
# Class: WHITE CRESTED HORNBILL, Index: 508
# Class: WHITE EARED HUMMINGBIRD, Index: 509
# Class: WHITE NECKED RAVEN, Index: 510
# Class: WHITE TAILED TROPIC, Index: 511
# Class: WHITE THROATED BEE EATER, Index: 512
# Class: WILD TURKEY, Index: 513
# Class: WILLOW PTARMIGAN, Index: 514
# Class: WILSONS BIRD OF PARADISE, Index: 515
# Class: WOOD DUCK, Index: 516
# Class: WOOD THRUSH, Index: 517
# Class: WOODLAND KINGFISHER, Index: 518
# Class: WRENTIT, Index: 519
# Class: YELLOW BELLIED FLOWERPECKER, Index: 520
# Class: YELLOW BREASTED CHAT, Index: 521
# Class: YELLOW CACIQUE, Index: 522
# Class: YELLOW HEADED BLACKBIRD, Index: 523
# Class: ZEBRA DOVE, Index: 524
# Batch 1 - Inputs: tensor([[[[0.9451, 0.9294, 0.9137,  ..., 0.7922, 0.7922, 0.8000],
#           [0.9373, 0.9255, 0.9098,  ..., 0.8000, 0.8000, 0.8039],
#           [0.9333, 0.9216, 0.9098,  ..., 0.8039, 0.8039, 0.8078],
#           ...,
#           [0.8078, 0.7804, 0.7843,  ..., 0.6118, 0.6431, 0.7373],
#           [0.8157, 0.7725, 0.7569,  ..., 0.6510, 0.6627, 0.7529],
#           [0.8196, 0.7647, 0.7137,  ..., 0.6431, 0.6902, 0.8039]],
#
#          [[0.9216, 0.9059, 0.8902,  ..., 0.7725, 0.7725, 0.7843],
#           [0.9137, 0.9020, 0.8863,  ..., 0.7804, 0.7804, 0.7843],
#           [0.9098, 0.8980, 0.8824,  ..., 0.7843, 0.7843, 0.7882],
#           ...,
#           [0.8078, 0.7843, 0.7843,  ..., 0.5725, 0.6157, 0.7176],
#           [0.8157, 0.7686, 0.7451,  ..., 0.6392, 0.6510, 0.7490],
#           [0.8196, 0.7647, 0.6980,  ..., 0.6549, 0.6980, 0.8196]],
#
#          [[0.8745, 0.8588, 0.8431,  ..., 0.6941, 0.6863, 0.6863],
#           [0.8667, 0.8549, 0.8392,  ..., 0.7020, 0.6980, 0.6941],
#           [0.8588, 0.8471, 0.8314,  ..., 0.7059, 0.7059, 0.7020],
#           ...,
#           [0.5255, 0.5098, 0.5294,  ..., 0.4392, 0.4588, 0.5294],
#           [0.5412, 0.5059, 0.5059,  ..., 0.4667, 0.4745, 0.5490],
#           [0.5451, 0.5098, 0.4745,  ..., 0.4471, 0.5020, 0.6196]]],
#
#
#         [[[0.5373, 0.5725, 0.6431,  ..., 0.7176, 0.7216, 0.7216],
#           [0.5412, 0.5765, 0.6471,  ..., 0.7176, 0.7216, 0.7216],
#           [0.5451, 0.5804, 0.6510,  ..., 0.7176, 0.7216, 0.7216],
#           ...,
#           [0.7255, 0.7255, 0.7255,  ..., 0.7294, 0.7294, 0.7294],
#           [0.7255, 0.7255, 0.7255,  ..., 0.7294, 0.7294, 0.7294],
#           [0.7255, 0.7255, 0.7255,  ..., 0.7294, 0.7294, 0.7294]],
#
#          [[0.4235, 0.4627, 0.5412,  ..., 0.7882, 0.7922, 0.7922],
#           [0.4275, 0.4627, 0.5412,  ..., 0.7882, 0.7922, 0.7922],
#           [0.4314, 0.4667, 0.5412,  ..., 0.7882, 0.7922, 0.7922],
#           ...,
#           [0.7961, 0.7961, 0.7961,  ..., 0.7961, 0.7961, 0.7961],
#           [0.7961, 0.7961, 0.7961,  ..., 0.7961, 0.7961, 0.7961],
#           [0.7961, 0.7961, 0.7961,  ..., 0.7961, 0.7961, 0.7961]],
#
#          [[0.1961, 0.2353, 0.3098,  ..., 0.8431, 0.8471, 0.8471],
#           [0.2000, 0.2392, 0.3098,  ..., 0.8431, 0.8471, 0.8471],
#           [0.2078, 0.2471, 0.3137,  ..., 0.8431, 0.8471, 0.8471],
#           ...,
#           [0.8510, 0.8510, 0.8510,  ..., 0.8588, 0.8588, 0.8588],
#           [0.8510, 0.8510, 0.8510,  ..., 0.8588, 0.8588, 0.8588],
#           [0.8510, 0.8510, 0.8510,  ..., 0.8588, 0.8588, 0.8588]]],
#
#
#         [[[0.3333, 0.2941, 0.2627,  ..., 0.6784, 0.6784, 0.6706],
#           [0.3451, 0.3137, 0.2902,  ..., 0.6784, 0.6824, 0.6784],
#           [0.3725, 0.3490, 0.3216,  ..., 0.6745, 0.6863, 0.6863],
#           ...,
#           [0.5020, 0.4980, 0.4745,  ..., 0.5137, 0.4627, 0.4510],
#           [0.4902, 0.4745, 0.4353,  ..., 0.5216, 0.4824, 0.4588],
#           [0.5373, 0.4980, 0.4275,  ..., 0.5373, 0.5216, 0.5059]],
#
#          [[0.4392, 0.4000, 0.3686,  ..., 0.7922, 0.7922, 0.7843],
#           [0.4471, 0.4157, 0.3922,  ..., 0.7922, 0.7961, 0.7922],
#           [0.4745, 0.4510, 0.4275,  ..., 0.7882, 0.8000, 0.8000],
#           ...,
#           [0.3647, 0.3725, 0.3725,  ..., 0.4824, 0.4431, 0.4314],
#           [0.3765, 0.3725, 0.3529,  ..., 0.4941, 0.4627, 0.4392],
#           [0.4549, 0.4235, 0.3725,  ..., 0.5059, 0.4980, 0.4863]],
#
#          [[0.2627, 0.2235, 0.1922,  ..., 0.6118, 0.6118, 0.6039],
#           [0.2667, 0.2392, 0.2157,  ..., 0.6157, 0.6157, 0.6118],
#           [0.2824, 0.2588, 0.2353,  ..., 0.6196, 0.6196, 0.6196],
#           ...,
#           [0.3725, 0.3804, 0.3804,  ..., 0.5137, 0.4706, 0.4588],
#           [0.3725, 0.3725, 0.3647,  ..., 0.5216, 0.4902, 0.4667],
#           [0.4353, 0.4157, 0.3843,  ..., 0.5333, 0.5255, 0.5137]]],
#
#
#         ...,
#
#
#         [[[1.0000, 1.0000, 1.0000,  ..., 0.4667, 0.4549, 0.4510],
#           [1.0000, 1.0000, 1.0000,  ..., 0.4588, 0.4627, 0.4627],
#           [1.0000, 1.0000, 0.9961,  ..., 0.4549, 0.4706, 0.4706],
#           ...,
#           [0.4314, 0.3804, 0.4118,  ..., 0.8902, 0.8784, 0.8902],
#           [0.4118, 0.3412, 0.3686,  ..., 0.8941, 0.8980, 0.8902],
#           [0.3843, 0.4510, 0.4667,  ..., 0.9216, 0.8863, 0.8824]],
#
#          [[0.9804, 0.9843, 0.9882,  ..., 0.4784, 0.4667, 0.4627],
#           [0.9843, 0.9843, 0.9843,  ..., 0.4706, 0.4745, 0.4745],
#           [0.9843, 0.9804, 0.9804,  ..., 0.4667, 0.4824, 0.4824],
#           ...,
#           [0.4431, 0.3922, 0.4235,  ..., 0.8078, 0.8000, 0.8196],
#           [0.4235, 0.3529, 0.3804,  ..., 0.8118, 0.8196, 0.8118],
#           [0.3961, 0.4627, 0.4784,  ..., 0.8392, 0.8078, 0.8078]],
#
#          [[0.9059, 0.9098, 0.9137,  ..., 0.5137, 0.5020, 0.4980],
#           [0.9098, 0.9098, 0.9098,  ..., 0.4980, 0.5020, 0.5059],
#           [0.9098, 0.9059, 0.9059,  ..., 0.4941, 0.5098, 0.5098],
#           ...,
#           [0.4706, 0.4196, 0.4510,  ..., 0.7098, 0.6980, 0.7176],
#           [0.4471, 0.3804, 0.4078,  ..., 0.7059, 0.7137, 0.7020],
#           [0.4157, 0.4824, 0.5059,  ..., 0.7333, 0.7020, 0.6902]]],
#
#
#         [[[0.1529, 0.1529, 0.1529,  ..., 0.1020, 0.0980, 0.0980],
#           [0.1529, 0.1529, 0.1529,  ..., 0.0980, 0.0941, 0.0941],
#           [0.1569, 0.1569, 0.1569,  ..., 0.0902, 0.0902, 0.0902],
#           ...,
#           [0.0627, 0.0627, 0.0588,  ..., 0.0706, 0.0549, 0.0510],
#           [0.0588, 0.0588, 0.0549,  ..., 0.0902, 0.0784, 0.0745],
#           [0.0588, 0.0588, 0.0549,  ..., 0.1098, 0.0980, 0.0941]],
#
#          [[0.2902, 0.2902, 0.2902,  ..., 0.2118, 0.2078, 0.2078],
#           [0.2941, 0.2941, 0.2941,  ..., 0.2118, 0.2078, 0.2078],
#           [0.2980, 0.2980, 0.2980,  ..., 0.2118, 0.2118, 0.2118],
#           ...,
#           [0.0863, 0.0863, 0.0902,  ..., 0.0627, 0.0588, 0.0588],
#           [0.0824, 0.0824, 0.0863,  ..., 0.0706, 0.0667, 0.0667],
#           [0.0824, 0.0824, 0.0863,  ..., 0.0784, 0.0784, 0.0784]],
#
#          [[0.1608, 0.1608, 0.1608,  ..., 0.0510, 0.0471, 0.0471],
#           [0.1608, 0.1608, 0.1608,  ..., 0.0510, 0.0471, 0.0471],
#           [0.1569, 0.1569, 0.1569,  ..., 0.0510, 0.0510, 0.0510],
#           ...,
#           [0.0471, 0.0471, 0.0471,  ..., 0.0353, 0.0314, 0.0275],
#           [0.0431, 0.0431, 0.0431,  ..., 0.0353, 0.0314, 0.0314],
#           [0.0431, 0.0431, 0.0431,  ..., 0.0392, 0.0353, 0.0353]]],
#
#
#         [[[0.6196, 0.6510, 0.6784,  ..., 0.5725, 0.5882, 0.6000],
#           [0.6353, 0.6627, 0.6824,  ..., 0.5569, 0.5725, 0.5882],
#           [0.6667, 0.6824, 0.6863,  ..., 0.5255, 0.5412, 0.5647],
#           ...,
#           [0.1294, 0.1333, 0.1373,  ..., 0.6941, 0.7020, 0.7098],
#           [0.1255, 0.1294, 0.1412,  ..., 0.6627, 0.6667, 0.6706],
#           [0.1216, 0.1294, 0.1451,  ..., 0.6471, 0.6471, 0.6510]],
#
#          [[0.5255, 0.5569, 0.5882,  ..., 0.4784, 0.4863, 0.4941],
#           [0.5412, 0.5686, 0.5961,  ..., 0.4627, 0.4745, 0.4863],
#           [0.5725, 0.5922, 0.6078,  ..., 0.4314, 0.4549, 0.4745],
#           ...,
#           [0.1098, 0.1176, 0.1176,  ..., 0.5765, 0.5882, 0.6000],
#           [0.1059, 0.1137, 0.1216,  ..., 0.5490, 0.5569, 0.5686],
#           [0.1020, 0.1098, 0.1255,  ..., 0.5333, 0.5412, 0.5490]],
#
#          [[0.3529, 0.3765, 0.3961,  ..., 0.4510, 0.4588, 0.4667],
#           [0.3686, 0.3882, 0.4039,  ..., 0.4314, 0.4431, 0.4549],
#           [0.4000, 0.4078, 0.4157,  ..., 0.4000, 0.4157, 0.4353],
#           ...,
#           [0.0784, 0.0824, 0.0863,  ..., 0.4941, 0.5020, 0.5137],
#           [0.0784, 0.0863, 0.0980,  ..., 0.4627, 0.4706, 0.4784],
#           [0.0784, 0.0863, 0.1020,  ..., 0.4471, 0.4549, 0.4588]]]]), Labels: tensor([ 99, 354, 282, 433, 259, 332, 120, 174, 490, 402, 368, 166, 217, 522,
#          36,  33, 140, 312, 440,  84, 188, 342, 190, 461, 477, 200, 197, 263,
#         463, 127, 105, 177])
# Batch 1 - Batch Size: 32
# cpu

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms, datasets, models
from sklearn.model_selection import train_test_split
from sklearn import metrics as skmetrics
import torch_xla
import torch_xla.core.xla_model as xm
import torch_xla.distributed.xla_multiprocessing as xmp
from torch.optim import lr_scheduler
from tqdm import tqdm
import time

# ... (Assuming you have some code here for data loading and preprocessing)

# Connect to TPU
device = xm.xla_device()
print("Running on TPU")

# Define the model, optimizer, and scheduler inside the _MP_fn to ensure proper TPU initialization
def _MP_fn(rank):
    # Load the EfficientNet-B4 architecture
    # Download the weights manually
    state_dict = torch.hub.load_state_dict_from_url("https://download.pytorch.org/models/efficientnet_b4_rwightman-7eb33cd5.pth")

    # Create the model
    model = models.efficientnet_b4(pretrained=True).to(device)

    # Load the weights
    model.load_state_dict(state_dict)
    
    # Freeze pre-trained weights
    for param in model.parameters():
        param.requires_grad = False

    # Modify the classifier
    classifier = nn.Sequential(
        nn.Linear(in_features=model.classifier[1].in_features, out_features=256, bias=True),
        nn.Linear(in_features=256, out_features=525, bias=True)
    )
    model.classifier = classifier
    
    # Move the model to TPU
    model.to(device)
    
    # Define the optimizer and scheduler
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

    # Training loop
    start_time = time.time()
    best_val_acc = 0
    print("Begin training process")
    
    for i in tqdm(range(0, num_epochs)):
        loss, val_loss, train_result, val_result = train_one_epoch(
            model,
            train_loader,
            valid_loader,
            device,
            optimizer,
            criterion,
            train_metrics,
            valid_metrics,
        )

        scheduler.step(val_loss)

        print("Epoch {} / {} \n Training loss: {} - Other training metrics: ".format(i + 1, num_epochs, loss))
        print(train_result)
        print(" \n Validation loss : {} - Other validation metrics:".format(val_loss))
        print(val_result)
        print("\n")

        # saving epoch with the best validation accuracy
        if best_val_acc < float(val_result["accuracy_score"]):
            print("Validation accuracy= " + str(val_result["accuracy_score"]) + "===> Save best epoch")
            best_val_acc = val_result["accuracy_score"]
            xm.save(model.state_dict(), "best.pt")
        else:
            print("Validation accuracy= " + str(val_result["accuracy_score"]) + "===> No saving")
            continue

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Total runtime first 10 epochs: {elapsed_time} seconds")

    for param in model.parameters():
        param.requires_grad = True

    optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0)

    start_time = time.time()
    best_val_acc = 0.8528
    print("Begin training process")
    
    for i in tqdm(range(0, num_epochs)):
        loss, val_loss, train_result, val_result = train_one_epoch(
            model,
            train_loader,
            valid_loader,
            device,
            optimizer,
            criterion,
            train_metrics,
            valid_metrics,
        )

        scheduler.step(val_loss)
        print("Epoch {} / {} \n Training loss: {} - Other training metrics: ".format(i + 1, num_epochs, loss))
        print(train_result)
        print(" \n Validation loss : {} - Other validation metrics:".format(val_loss))
        print(val_result)
        print("\n")

        # saving epoch with best validation accuracy
        if best_val_acc < float(val_result["accuracy_score"]):
            print("Validation accuracy= " + str(val_result["accuracy_score"]) + "===> Save best epoch")
            best_val_acc = val_result["accuracy_score"]
            xm.save(model.state_dict(), "best.pt")
        else:
            print("Validation accuracy= " + str(val_result["accuracy_score"]) + "===> No saving")
            continue

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(f"Total runtime next 10 epochs: {elapsed_time} seconds")
# Out:
# Running on TPU

# %%
xmp.spawn(_MP_fn, args=(), nprocs=8, start_method='fork')
# Out:
# WARNING:root:Unsupported nprocs (8), ignoring...
